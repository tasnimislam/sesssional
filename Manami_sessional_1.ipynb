# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-83bc6d7d-4499-4d8f-ad87-19a856fae200" name="files[]" multiple disabled />
#      <output id="result-83bc6d7d-4499-4d8f-ad87-19a856fae200">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.png to download.png
# User uploaded file "download.png" with length 11098 bytes

# %%
import os
# !ls
os.getcwd()
# Out:
# download.png  sample_data
# '/content'

# %%
from PIL import Image
image_path='/content/download.png'
image=Image.open(image_path)
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=236x136 at 0x7F346B183828>

# %%
image.size
# Out:
# (236, 136)

# %%
image.show()

# %%
image=image.resize((224,224), Image.ANTIALIAS)
image.size
# Out:
# (224, 224)

# %%
display(image
      )
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F346B1DA240>

# %%
image=image.resize((236,136),Image.ANTIALIAS)
image.size
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=236x136 at 0x7F346B0FEC50>

# %%
size=128,232
image.thumbnail(size,Image.ANTIALIAS)
image.size
# Out:
# (128, 73)
